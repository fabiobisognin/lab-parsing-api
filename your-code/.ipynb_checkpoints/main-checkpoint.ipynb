# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
import re
import json
import requests
import urllib.request
from base64 import b64encode
import pandas as pd
from pandas.io.json import json_normalize

# %%
url='https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84'

# %%
response = urllib.request.urlopen(url)
results = json.load(response)
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# <ipython-input-8-6d701c6a6fc6>:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-8-6d701c6a6fc6>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#               sku                                               name  \
# 0   SC922A002-112            DUNLIN 2 - Veste mi-saison - gris chine
# 1   CO411A00U-802  CHUCK TAYLOR ALL STAR HI - Baskets montantes -...
# 2   SU222O0Q7-K12  ORANGE LABEL VINTAGE TEE - T-shirt à manches l...
# 3   OS322E070-K11  ONSMARK PANT STRIPE - Pantalon classique - nig...
# 4   LA212O03J-A11                  GRADUATE - Baskets basses - white
# ..            ...                                                ...
# 79  JA222S11O-Q11  JJEHOLMEN - veste en sweat zippée - black/reg fit
# 80  TO122S096-K11                LOGO HOODY - Sweat à capuche - blue
# 81  JA222S135-Q11        JJECORP LOGO HOOD - Sweat à capuche - black
# 82  C0822S01E-K11             CREW NECK - Sweatshirt - total eclipse
# 83  TO122O0D6-A11               STRIPE TEE - T-shirt imprimé - white
#
#                                                 sizes  \
# 0                             [S, M, L, XL, XXL, 3XL]
# 1   [35, 36, 36.5, 37, 37.5, 39.5, 40, 41, 41.5, 4...
# 2               [XXS, XS, S, M, L, XL, XXL, 3XL, 4XL]
# 3   [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# 4   [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 46,...
# ..                                                ...
# 79                             [XS, S, M, L, XL, XXL]
# 80                        [XS, S, M, L, XL, XXL, 3XL]
# 81                                      [S, M, L, XL]
# 82                                 [S, M, L, XL, XXL]
# 83                        [XS, S, M, L, XL, XXL, 3XL]
#
#                                               url_key  \
# 0   schott-nyc-dunlin-2-gilet-en-laine-gris-sc922a...
# 1       converse-as-hi-can-baskets-noir-co411a00u-802
# 2   superdry-orange-label-t-shirt-a-manches-longue...
# 3   only-and-sons-onsmark-pant-stripe-pantalon-cla...
# 4       lacoste-graduate-baskets-basses-la212o03j-a11
# ..                                                ...
# 79  jack-and-jones-jjeholmen-zip-hood-regular-fit-...
# 80  tommy-hilfiger-logo-hoody-sweatshirt-to122s096...
# 81       jack-and-jones-logo-sweatshirt-ja222s135-q11
# 82  cp-company-crew-neck-sweatshirt-total-eclipse-...
# 83  tommy-hilfiger-stripe-tee-t-shirt-imprime-whit...
#
#                                                 media      brand_name  \
# 0   [{'path': 'spp-media-p1/d66f8abb30b132208e4b3e...          Schott
# 1   [{'path': 'spp-media-p1/6597bcab8b48370a928a5c...        Converse
# 2   [{'path': 'spp-media-p1/8918fa849656309496c360...        Superdry
# 3   [{'path': 'spp-media-p1/fc556fa73841364daa055e...     Only & Sons
# 4   [{'path': 'spp-media-p1/f1e1bb30b1a73a6f96d80a...         Lacoste
# ..                                                ...             ...
# 79  [{'path': 'spp-media-p1/7266b20dd9b53129bad603...    Jack & Jones
# 80  [{'path': 'spp-media-p1/2be041b3493c3f9daad0ab...  Tommy Hilfiger
# 81  [{'path': 'spp-media-p1/cce3e51c54793fd7a1c73f...    Jack & Jones
# 82  [{'path': 'spp-media-p1/8d5797249cb7333792657b...    C.P. Company
# 83  [{'path': 'spp-media-p1/284384ec9b6e3d80bdc86f...  Tommy Hilfiger
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82        True              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': 'Jusqu’à -14...          shoe
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -30...      clothing
# 3   [{'key': 'discountRate', 'value': 'Jusqu’à -30...      clothing
# 4   [{'key': 'discountRate', 'value': '-45%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': 'Jusqu’à -20...      clothing
# 81  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        99,95 €           69,95 €
# 1                 []        69,90 €           59,90 €
# 2                 []        39,99 €           27,99 €
# 3                 []        43,99 €           30,79 €
# 4                 []        94,95 €           51,95 €
# ..               ...            ...               ...
# 79                []        29,99 €           22,49 €
# 80                []       104,95 €           83,95 €
# 81                []        29,99 €           26,99 €
# 82                []       144,95 €          108,95 €
# 83                []        37,95 €           26,55 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                         True                                False
# 2                         True                                False
# 3                         True                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                        True                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                    True
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only outfits
# 0                                       False     NaN
# 1                                       False     NaN
# 2                                       False     NaN
# 3                                       False     NaN
# 4                                       False     NaN
# ..                                        ...     ...
# 79                                      False     NaN
# 80                                      False     NaN
# 81                                      False     NaN
# 82                                      False     NaN
# 83                                      False     NaN
#
# [84 rows x 18 columns]

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
df=pd.DataFrame()
for i in range(2):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84{k}&sort=sale'
    request = urllib.request.urlopen(url)
    data = json.load(request)
    flattened_data = pd.json_normalize(data)
    flattened_data1 = pd.json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
df
# Out:
#                                                             name  \
# sku
# SU222S0QA-C11         SHOP DUO HOOD - Sweat à capuche - ice marl
# NI122O0J6-A11                            T-shirt imprimé - white
# YO121001P-A11                  T-shirt à manches longues - white
# C7642K01I-G11  LEGACY TAPE TRACKSUIT SET - Survêtement - red/...
# JA222S1MB-M11                        Sweatshirt - trekking green
# ...                                                          ...
# SE622A0HW-K11    SLHSLIM HOUND  SUIT SET - Costume - ashley blue
# NER22S00B-C11                   CHEST STRIPE - Sweatshirt - grey
# 4BE22O03F-E11                             T-shirt basique - ocra
# DI112O02E-B11  SERENDIPITY S-SERENDIPITY LOW SNEAKERS - Baske...
# DEZ22P00P-A11                                       Polo - white
#
#                                                sizes  \
# sku
# SU222S0QA-C11            [XS, S, M, L, XL, XXL, 3XL]
# NI122O0J6-A11                 [XS, S, M, L, XL, XXL]
# YO121001P-A11            [XXS, XS, S, M, L, XL, XXL]
# C7642K01I-G11                     [S, M, L, XL, XXL]
# JA222S1MB-M11                 [XS, S, M, L, XL, XXL]
# ...                                              ...
# SE622A0HW-K11  [46, 48, 50, 52, 54, 56, 94, 98, 106]
# NER22S00B-C11                          [XS, S, M, L]
# 4BE22O03F-E11                 [XS, S, M, L, XL, XXL]
# DI112O02E-B11                       [39, 43, 44, 45]
# DEZ22P00P-A11            [XS, S, M, L, XL, XXL, 3XL]
#
#                                                          url_key  \
# sku
# SU222S0QA-C11    superdry-shop-duo-hood-sweatshirt-su222s0qa-c11
# NI122O0J6-A11  nike-sportswear-t-shirt-imprime-white-ni122o0j...
# YO121001P-A11  yourturn-t-shirt-a-manches-longues-white-yo121...
# C7642K01I-G11  champion-legacy-tape-tracksuit-set-survetement...
# JA222S1MB-M11  jack-and-jones-jorpipe-crew-neck-sweatshirt-tr...
# ...                                                          ...
# SE622A0HW-K11  selected-homme-slhslim-costume-ashley-blue-se6...
# NER22S00B-C11  newport-bay-sailing-club-chest-stripe-sweatshi...
# 4BE22O03F-E11        benetton-t-shirt-basique-ocra-4be22o03f-e11
# DI112O02E-B11  diesel-serendipity-s-serendipity-low-sneakers-...
# DEZ22P00P-A11                   defacto-polo-white-dez22p00p-a11
#
#                                                            media  \
# sku
# SU222S0QA-C11  [{'path': 'spp-media-p1/5150167c88a3394d8ca4c0...
# NI122O0J6-A11  [{'path': 'spp-media-p1/bf0b9059ce813c248e811f...
# YO121001P-A11  [{'path': 'spp-media-p1/e4becef537343d789e7091...
# C7642K01I-G11  [{'path': 'spp-media-p1/c89798bf17163b5e996638...
# JA222S1MB-M11  [{'path': 'spp-media-p1/49de4832d45a316ab67cc1...
# ...                                                          ...
# SE622A0HW-K11  [{'path': 'spp-media-p1/7b45cf260f073ae183d0af...
# NER22S00B-C11  [{'path': 'spp-media-p1/a134e402a7ac33a5829691...
# 4BE22O03F-E11  [{'path': 'spp-media-p1/eed98e78b4e43778a437c3...
# DI112O02E-B11  [{'path': 'spp-media-p1/926b8063706f35dfa5e742...
# DEZ22P00P-A11  [{'path': 'spp-media-p1/790187063e133037850f68...
#
#                              brand_name  is_premium family_articles  \
# sku
# SU222S0QA-C11                  Superdry       False              []
# NI122O0J6-A11           Nike Sportswear       False              []
# YO121001P-A11                  YOURTURN       False              []
# C7642K01I-G11                  Champion       False              []
# JA222S1MB-M11              Jack & Jones       False              []
# ...                                 ...         ...             ...
# SE622A0HW-K11            Selected Homme       False              []
# NER22S00B-C11  Newport Bay Sailing Club       False              []
# 4BE22O03F-E11                  Benetton       False              []
# DI112O02E-B11                    Diesel       False              []
# DEZ22P00P-A11                   DeFacto       False              []
#
#                                                            flags  \
# sku
# SU222S0QA-C11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# NI122O0J6-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# YO121001P-A11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# C7642K01I-G11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# JA222S1MB-M11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# ...                                                          ...
# SE622A0HW-K11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# NER22S00B-C11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# 4BE22O03F-E11  [{'key': 'discountRate', 'value': '-10%', 'tra...
# DI112O02E-B11  [{'key': 'discountRate', 'value': '-50%', 'tra...
# DEZ22P00P-A11  [{'key': 'discountRate', 'value': '-50%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# SU222S0QA-C11      clothing                []        79,99 €
# NI122O0J6-A11      clothing                []        24,95 €
# YO121001P-A11      clothing                []        14,99 €
# C7642K01I-G11      clothing                []        69,95 €
# JA222S1MB-M11      clothing                []        29,99 €
# ...                     ...               ...            ...
# SE622A0HW-K11      clothing                []       254,99 €
# NER22S00B-C11      clothing                []        24,95 €
# 4BE22O03F-E11      clothing                []        12,95 €
# DI112O02E-B11          shoe                []       129,95 €
# DEZ22P00P-A11      clothing                []        19,99 €
#
#               price.promotional  price.has_different_prices  \
# sku
# SU222S0QA-C11           55,99 €                        True
# NI122O0J6-A11           17,45 €                        True
# YO121001P-A11           12,79 €                       False
# C7642K01I-G11           55,95 €                       False
# JA222S1MB-M11           23,99 €                       False
# ...                         ...                         ...
# SE622A0HW-K11          191,99 €                       False
# NER22S00B-C11           18,75 €                       False
# 4BE22O03F-E11           11,65 €                       False
# DI112O02E-B11           64,95 €                       False
# DEZ22P00P-A11            9,99 €                       False
#
#                price.has_different_original_prices  \
# sku
# SU222S0QA-C11                                False
# NI122O0J6-A11                                False
# YO121001P-A11                                False
# C7642K01I-G11                                False
# JA222S1MB-M11                                False
# ...                                            ...
# SE622A0HW-K11                                False
# NER22S00B-C11                                False
# 4BE22O03F-E11                                False
# DI112O02E-B11                                False
# DEZ22P00P-A11                                False
#
#                price.has_different_promotional_prices  \
# sku
# SU222S0QA-C11                                    True
# NI122O0J6-A11                                    True
# YO121001P-A11                                   False
# C7642K01I-G11                                   False
# JA222S1MB-M11                                   False
# ...                                               ...
# SE622A0HW-K11                                   False
# NER22S00B-C11                                   False
# 4BE22O03F-E11                                   False
# DI112O02E-B11                                   False
# DEZ22P00P-A11                                   False
#
#                price.has_discount_on_selected_sizes_only outfits amount
# sku
# SU222S0QA-C11                                      False     NaN    NaN
# NI122O0J6-A11                                      False     NaN    NaN
# YO121001P-A11                                      False     NaN    NaN
# C7642K01I-G11                                      False     NaN    NaN
# JA222S1MB-M11                                      False     NaN    NaN
# ...                                                  ...     ...    ...
# SE622A0HW-K11                                      False     NaN    NaN
# NER22S00B-C11                                      False     NaN    NaN
# 4BE22O03F-E11                                      False     NaN    NaN
# DI112O02E-B11                                      False     NaN    NaN
# DEZ22P00P-A11                                      False     NaN    NaN
#
# [168 rows x 18 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
df.brand_name.value_counts().index[0]
# Out:
# 'Jack & Jones'

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')
df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)

# %%
df1=df.copy()
df1
# Out:
#                                                             name  \
# sku
# SU222S0QA-C11         SHOP DUO HOOD - Sweat à capuche - ice marl
# NI122O0J6-A11                            T-shirt imprimé - white
# YO121001P-A11                  T-shirt à manches longues - white
# C7642K01I-G11  LEGACY TAPE TRACKSUIT SET - Survêtement - red/...
# JA222S1MB-M11                        Sweatshirt - trekking green
# ...                                                          ...
# SE622A0HW-K11    SLHSLIM HOUND  SUIT SET - Costume - ashley blue
# NER22S00B-C11                   CHEST STRIPE - Sweatshirt - grey
# 4BE22O03F-E11                             T-shirt basique - ocra
# DI112O02E-B11  SERENDIPITY S-SERENDIPITY LOW SNEAKERS - Baske...
# DEZ22P00P-A11                                       Polo - white
#
#                                                sizes  \
# sku
# SU222S0QA-C11            [XS, S, M, L, XL, XXL, 3XL]
# NI122O0J6-A11                 [XS, S, M, L, XL, XXL]
# YO121001P-A11            [XXS, XS, S, M, L, XL, XXL]
# C7642K01I-G11                     [S, M, L, XL, XXL]
# JA222S1MB-M11                 [XS, S, M, L, XL, XXL]
# ...                                              ...
# SE622A0HW-K11  [46, 48, 50, 52, 54, 56, 94, 98, 106]
# NER22S00B-C11                          [XS, S, M, L]
# 4BE22O03F-E11                 [XS, S, M, L, XL, XXL]
# DI112O02E-B11                       [39, 43, 44, 45]
# DEZ22P00P-A11            [XS, S, M, L, XL, XXL, 3XL]
#
#                                                          url_key  \
# sku
# SU222S0QA-C11    superdry-shop-duo-hood-sweatshirt-su222s0qa-c11
# NI122O0J6-A11  nike-sportswear-t-shirt-imprime-white-ni122o0j...
# YO121001P-A11  yourturn-t-shirt-a-manches-longues-white-yo121...
# C7642K01I-G11  champion-legacy-tape-tracksuit-set-survetement...
# JA222S1MB-M11  jack-and-jones-jorpipe-crew-neck-sweatshirt-tr...
# ...                                                          ...
# SE622A0HW-K11  selected-homme-slhslim-costume-ashley-blue-se6...
# NER22S00B-C11  newport-bay-sailing-club-chest-stripe-sweatshi...
# 4BE22O03F-E11        benetton-t-shirt-basique-ocra-4be22o03f-e11
# DI112O02E-B11  diesel-serendipity-s-serendipity-low-sneakers-...
# DEZ22P00P-A11                   defacto-polo-white-dez22p00p-a11
#
#                                                            media  \
# sku
# SU222S0QA-C11  [{'path': 'spp-media-p1/5150167c88a3394d8ca4c0...
# NI122O0J6-A11  [{'path': 'spp-media-p1/bf0b9059ce813c248e811f...
# YO121001P-A11  [{'path': 'spp-media-p1/e4becef537343d789e7091...
# C7642K01I-G11  [{'path': 'spp-media-p1/c89798bf17163b5e996638...
# JA222S1MB-M11  [{'path': 'spp-media-p1/49de4832d45a316ab67cc1...
# ...                                                          ...
# SE622A0HW-K11  [{'path': 'spp-media-p1/7b45cf260f073ae183d0af...
# NER22S00B-C11  [{'path': 'spp-media-p1/a134e402a7ac33a5829691...
# 4BE22O03F-E11  [{'path': 'spp-media-p1/eed98e78b4e43778a437c3...
# DI112O02E-B11  [{'path': 'spp-media-p1/926b8063706f35dfa5e742...
# DEZ22P00P-A11  [{'path': 'spp-media-p1/790187063e133037850f68...
#
#                              brand_name  is_premium family_articles  \
# sku
# SU222S0QA-C11                  Superdry       False              []
# NI122O0J6-A11           Nike Sportswear       False              []
# YO121001P-A11                  YOURTURN       False              []
# C7642K01I-G11                  Champion       False              []
# JA222S1MB-M11              Jack & Jones       False              []
# ...                                 ...         ...             ...
# SE622A0HW-K11            Selected Homme       False              []
# NER22S00B-C11  Newport Bay Sailing Club       False              []
# 4BE22O03F-E11                  Benetton       False              []
# DI112O02E-B11                    Diesel       False              []
# DEZ22P00P-A11                   DeFacto       False              []
#
#                                                            flags  \
# sku
# SU222S0QA-C11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# NI122O0J6-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# YO121001P-A11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# C7642K01I-G11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# JA222S1MB-M11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# ...                                                          ...
# SE622A0HW-K11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# NER22S00B-C11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# 4BE22O03F-E11  [{'key': 'discountRate', 'value': '-10%', 'tra...
# DI112O02E-B11  [{'key': 'discountRate', 'value': '-50%', 'tra...
# DEZ22P00P-A11  [{'key': 'discountRate', 'value': '-50%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# SU222S0QA-C11      clothing                []          79.99
# NI122O0J6-A11      clothing                []          24.95
# YO121001P-A11      clothing                []          14.99
# C7642K01I-G11      clothing                []          69.95
# JA222S1MB-M11      clothing                []          29.99
# ...                     ...               ...            ...
# SE622A0HW-K11      clothing                []         254.99
# NER22S00B-C11      clothing                []          24.95
# 4BE22O03F-E11      clothing                []          12.95
# DI112O02E-B11          shoe                []         129.95
# DEZ22P00P-A11      clothing                []          19.99
#
#               price.promotional  price.has_different_prices  \
# sku
# SU222S0QA-C11             55.99                        True
# NI122O0J6-A11             17.45                        True
# YO121001P-A11             12.79                       False
# C7642K01I-G11             55.95                       False
# JA222S1MB-M11             23.99                       False
# ...                         ...                         ...
# SE622A0HW-K11            191.99                       False
# NER22S00B-C11             18.75                       False
# 4BE22O03F-E11             11.65                       False
# DI112O02E-B11             64.95                       False
# DEZ22P00P-A11              9.99                       False
#
#                price.has_different_original_prices  \
# sku
# SU222S0QA-C11                                False
# NI122O0J6-A11                                False
# YO121001P-A11                                False
# C7642K01I-G11                                False
# JA222S1MB-M11                                False
# ...                                            ...
# SE622A0HW-K11                                False
# NER22S00B-C11                                False
# 4BE22O03F-E11                                False
# DI112O02E-B11                                False
# DEZ22P00P-A11                                False
#
#                price.has_different_promotional_prices  \
# sku
# SU222S0QA-C11                                    True
# NI122O0J6-A11                                    True
# YO121001P-A11                                   False
# C7642K01I-G11                                   False
# JA222S1MB-M11                                   False
# ...                                               ...
# SE622A0HW-K11                                   False
# NER22S00B-C11                                   False
# 4BE22O03F-E11                                   False
# DI112O02E-B11                                   False
# DEZ22P00P-A11                                   False
#
#                price.has_discount_on_selected_sizes_only outfits amount  \
# sku
# SU222S0QA-C11                                      False     NaN    NaN
# NI122O0J6-A11                                      False     NaN    NaN
# YO121001P-A11                                      False     NaN    NaN
# C7642K01I-G11                                      False     NaN    NaN
# JA222S1MB-M11                                      False     NaN    NaN
# ...                                                  ...     ...    ...
# SE622A0HW-K11                                      False     NaN    NaN
# NER22S00B-C11                                      False     NaN    NaN
# 4BE22O03F-E11                                      False     NaN    NaN
# DI112O02E-B11                                      False     NaN    NaN
# DEZ22P00P-A11                                      False     NaN    NaN
#
#                discount_amount
# sku
# SU222S0QA-C11             24.0
# NI122O0J6-A11              7.5
# YO121001P-A11              2.2
# C7642K01I-G11             14.0
# JA222S1MB-M11              6.0
# ...                        ...
# SE622A0HW-K11             63.0
# NER22S00B-C11              6.2
# 4BE22O03F-E11              1.3
# DI112O02E-B11             65.0
# DEZ22P00P-A11             10.0
#
# [168 rows x 19 columns]
