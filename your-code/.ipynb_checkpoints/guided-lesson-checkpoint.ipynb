# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import re
import json
import requests
import urllib.request
from base64 import b64encode
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %%
# Your code

response = urllib.request.urlopen(url)
results = json.load(response)
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# <ipython-input-27-e5b263037047>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-27-e5b263037047>:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#               sku                                               name  \
# 0   MPA83D00D-K11   LAMIIUM 2 PACK - Chaussettes - deep navy/mustard
# 1   MPA83D00F-K11  CLEMATIS 2 PACK - Chaussettes - dark navy/ston...
# 2   JH184A02U-K11                   SIDE CLOSING - Body - china blue
# 3   FA186D03D-K11                  ACTIVE FOX - Chaussettes - marine
# 4   HU343I006-J11      SEAMLESS  - Soutien-gorge de sport - ash rose
# 5   FA186D03A-A11                       SOCCER - Chaussettes - white
# 6   FA186D03D-M11             ACTIVE FOX - Chaussettes - grass green
# 7   MPA83D003-J11                       FIPPE BABY - Collants - rosa
# 8   WHA86A003-K11                         THUMPER BABY - Body - dove
# 9   FA183D02E-Q11                  2 PACK - Chaussettes - black/grey
# 10  GP086B00R-C11                 ICON - Pyjama - light heather grey
# 11  V2083B00O-A11    WOLFI - Chemise de nuit / Nuisette - real white
# 12  AB383A08C-T11                      LOT 2 PACK - Body - bleu ciel
# 13  CL883A04I-J11               GIRLS 2 PACK SINGLET - Caraco - pink
# 14  HU343I004-M11         MIMMI - Soutien-gorge de sport - green ash
# 15  CL883A04J-A11              GIRLS 2 PACK SINGLET - Caraco - white
# 16  K4826D000-A11    SCHLAFANZUG LAETZCHEN SET - Pyjama - noir/blanc
# 17  JH184B019-K11                        ROMPER FOOT - Pyjama - blue
# 18  M8584B006-T12                        WAY - Peignoir - multicolor
# 19  M8543I003-A11            OLIVIA - Soutien-gorge de sport - white
# 20  M8543I003-J12             OLIVIA - Soutien-gorge de sport - pink
# 21  HY583A003-T11           KIDS SET - Set de sous-vêtements - multi
# 22  M8543I003-J11       OLIVIA - Soutien-gorge de sport - pink/black
# 23  HY583A006-T11    KIDS SPACE SET  - Set de sous-vêtements - multi
# 24  HC386A00K-A11                            BABY - Body - off-white
# 25  SG986A005-I11                       BUTTERCUP - Body - dawn pink
# 26  S0T86A00B-M11         BABY 3 PACK - Body - green/navy/lilac grey
# 27  SG986A009-M11                   FRASER BODY MILKY - Body - swamp
# 28  DK183A001-T11              SET  - Set de sous-vêtements - unique
# 29  DK183A000-Q11  ENSEMBLE LEIBCHEN 2 PACK SET - Set de sous-vêt...
# 30  SA186B00D-M11                     BATHROBE - Peignoir - new lime
# 31  JH184D000-K12                                    Collants - blau
# 32  JH186A01I-A11                                   Body - off white
# 33  JH186A01A-J11                                 BABY - Body - rose
# 34  JH186A01J-K11                      SHORT SLEEVES - Body - marine
# 35  JH186A01G-J11                                        Body - rosa
# 36  JH186A01A-C11                                 BABY - Body - grey
# 37  JH186A01K-A11                       SHORT SLEEVES - Body - white
# 38  M8583A00I-T11                     JOSHLYN  - Caraco - multicolor
# 39  M8583A00I-T12                     JOSHLYN  - Caraco - multicolor
# 40  JH186A01A-K11                                 BABY - Body - blue
# 41  TO183A03C-J11                           TEE LOGO - Caraco - pink
# 42  1VE83A001-F11                  MANICA CORTA BABY - Body - bianco
# 43  V2083A01N-J11               TIGER SINGLET - Caraco - pink fusion
# 44  WHA86B002-K11                       THUMPER BABY - Pyjama - dove
# 45  JH184A02T-K11                   LONG SLEEVES - Body - china blue
# 46  1VE24D000-J11               REGALO BABY SET - Body - rosa/stampa
#
#                sizes                                            url_key  \
# 0            [40-42]  mp-denmark-lamiium-2-pack-chaussettes-deep-nav...
# 1            [40-42]  mp-denmark-clematis-2-pack-chaussettes-dark-na...
# 2                 []    joha-side-closing-body-china-blue-jh184a02u-k11
# 3     [19-22, 23-26]         falke-active-fox-chaussettes-fa186d03d-k11
# 4             [5-6a]  hummel-seamless-soutien-gorge-de-sport-ash-ros...
# 5     [23-26, 39-42]       falke-soccer-chaussettes-white-fa186d03a-a11
# 6     [19-22, 23-26]  falke-active-fox-chaussettes-grass-green-fa186...
# 7             [0-3m]  mp-denmark-fippe-baby-collants-rosa-mpa83d003-j11
# 8               [3m]         wheat-thumper-baby-body-dove-wha86a003-k11
# 9            [31-34]   falke-2-pack-chaussettes-blackgrey-fa183d02e-q11
# 10            [6-9m]   gap-icon-pyjama-light-heather-grey-gp086b00r-c11
# 11             [16a]  vingino-wolfi-chemise-de-nuit--nuisette-real-w...
# 12         , 12m]              absorba-lot-2-pack-body-ab383a08c-t11
# 13              [2a]  claesens-girls-2-pack-singlet-caraco-pink-cl88...
# 14      [4a, 6a, 7a]  hummel-mimmi-sports-soutien-gorge-de-sport-hu3...
# 15              [6a]  claesens-girls-2-pack-singlet-caraco-white-cl8...
# 16             [18m]  karl-lagerfeld-schlafanzug-laetzchen-set-pyjam...
# 17            [0-1m]   joha-romper-foot-grenouillere-blue-jh184b019-k11
# 18           [9-10a]                    molo-way-peignoir-m8584b006-t12
# 19          [15-16a]   molo-olivia-soutien-gorge-de-sport-m8543i003-a11
# 20  [13-14a, 15-16a]  molo-olivia-soutien-gorge-de-sport-pink-m8543i...
# 21            [7-8a]  hype-kids-set-set-de-sous-vetements-multi-hy58...
# 22          [15-16a]   molo-olivia-soutien-gorge-de-sport-m8543i003-j11
# 23      [5-6a, 7-8a]  hype-kids-space-set-set-de-sous-vetements-mult...
# 24              [0m]  hust-and-claire-baby-body-off-white-hc386a00k-a11
# 25     , 24m/2y]  soft-gallery-buttercup-body-dawn-pink-sg986a00...
# 26            [0-3m]  sense-organics-baby-3-pack-body-greennavylilac...
# 27             [18m]  soft-gallery-fraser-body-milky-body-swamp-sg98...
# 28             [16a]  dkny-set-set-de-sous-vetements-unique-dk183a00...
# 29              [8a]  dkny-ensemble-leibchen-set-set-de-sous-vetemen...
# 30          [15-16a]   sanetta-bathrobe-peignoir-new-lime-sa186b00d-m11
# 31      [0-1m, 1-4m]                   joha-collants-blau-jh184d000-k12
# 32            [0-1m]                  joha-body-off-white-jh186a01i-a11
# 33            [0-1m]                       joha-baby-body-jh186a01a-j11
# 34            [0-1m]       joha-short-sleeves-body-marine-jh186a01j-k11
# 35            [0-1m]                       joha-body-rosa-jh186a01g-j11
# 36            [0-1m]                  joha-baby-body-grey-jh186a01a-c11
# 37            [0-1m]        joha-short-sleeves-body-white-jh186a01k-a11
# 38            [2-3a]       molo-joshlyn-caraco-multicolor-m8583a00i-t11
# 39            [2-3a]                  molo-joshlyn-caraco-m8583a00i-t12
# 40            [0-1m]                       joha-baby-body-jh186a01a-k11
# 41          [12-14a]  tommy-hilfiger-tee-logo-caraco-pink-to183a03c-j11
# 42            [6-9m]  versace-manica-corta-baby-body-bianco-1ve83a00...
# 43        [14a, 16a]  vingino-tiger-singlet-caraco-pink-fusion-v2083...
# 44              [6m]       wheat-thumper-baby-pyjama-dove-wha86b002-k11
# 45            [0-1m]    joha-long-sleeves-body-china-blue-jh184a02t-k11
# 46            [0-3m]  versace-regalo-baby-set-body-rosastampa-1ve24d...
#
#                                                 media      brand_name  \
# 0   [{'path': 'spp-media-p1/e66131b05e6a383680244d...      MP Denmark
# 1   [{'path': 'spp-media-p1/a7e2675d29c33aa4b59818...      MP Denmark
# 2   [{'path': 'spp-media-p1/e94606c34a25377b94304b...            Joha
# 3   [{'path': 'spp-media-p1/e39d65d2d8b9327b859253...           Falke
# 4   [{'path': 'spp-media-p1/c5ccbdfc67453f9db4f3bc...          Hummel
# 5   [{'path': 'spp-media-p1/dab06395d7153bc8870c02...           Falke
# 6   [{'path': 'spp-media-p1/2c44f596488a38b8a04c4c...           Falke
# 7   [{'path': 'spp-media-p1/df7ccb22912d3aec89d2d0...      MP Denmark
# 8   [{'path': 'spp-media-p1/2dc01d3bcccd3434826e90...           Wheat
# 9   [{'path': 'spp-media-p1/7a92b531f72830f6af6fd8...           Falke
# 10  [{'path': 'spp-media-p1/2f7ca45dcb3a342ca9b9e0...             GAP
# 11  [{'path': 'spp-media-p1/8413d2c534ec30369b39d2...         Vingino
# 12  [{'path': 'spp-media-p1/ce30bad117c33932a8c5ee...         Absorba
# 13  [{'path': 'spp-media-p1/9e379ac5c9173a0d810499...       Claesen‘s
# 14  [{'path': 'spp-media-p1/23043efa62f830529bb936...          Hummel
# 15  [{'path': 'spp-media-p1/9b46267b39c630378c0605...       Claesen‘s
# 16  [{'path': 'spp-media-p1/dc854d4d827d35b7825539...  KARL LAGERFELD
# 17  [{'path': 'spp-media-p1/3354c1807d3e32c1bca534...            Joha
# 18  [{'path': 'spp-media-p1/4269c66e59d6311186acd2...            Molo
# 19  [{'path': 'spp-media-p1/00e68293bf2a30c8b44dc0...            Molo
# 20  [{'path': 'spp-media-p1/7de4205ab145333184d69f...            Molo
# 21  [{'path': 'spp-media-p1/8650f895d60b3950b6a00c...            Hype
# 22  [{'path': 'spp-media-p1/fac7bfedae1e31afb0a607...            Molo
# 23  [{'path': 'spp-media-p1/4a8481c5a36234f6b7953a...            Hype
# 24  [{'path': 'spp-media-p1/1516ad0969303e399f9037...   Hust & Claire
# 25  [{'path': 'spp-media-p1/2c26c29a29983ae385e677...    Soft Gallery
# 26  [{'path': 'spp-media-p1/6b24e45a62ea36bebcf7ee...  Sense Organics
# 27  [{'path': 'spp-media-p1/3ea4b84892f039729632c5...    Soft Gallery
# 28  [{'path': 'spp-media-p1/58038a5ba81b3032b2b478...            DKNY
# 29  [{'path': 'spp-media-p1/4b9cc22989833362a4940b...            DKNY
# 30  [{'path': 'spp-media-p1/55cc1c357831323aab7575...         Sanetta
# 31  [{'path': 'spp-media-p1/57581287d70c38a1b6ccdf...            Joha
# 32  [{'path': 'spp-media-p1/c28f661ea07735b8bf2586...            Joha
# 33  [{'path': 'spp-media-p1/77ad99855d5c3d98a6ad88...            Joha
# 34  [{'path': 'spp-media-p1/f8368e16a8313d718d4e0c...            Joha
# 35  [{'path': 'spp-media-p1/567b7cbe0e443cbc89e0f2...            Joha
# 36  [{'path': 'spp-media-p1/1a4d7bcd67a73beaa2aaec...            Joha
# 37  [{'path': 'spp-media-p1/09104e604775322fb54a8e...            Joha
# 38  [{'path': 'spp-media-p1/e8d88ec089de3ad49ae2cd...            Molo
# 39  [{'path': 'spp-media-p1/a17e65e0e70d38758a1c8a...            Molo
# 40  [{'path': 'spp-media-p1/38f70b384e1a3b849da4bd...            Joha
# 41  [{'path': 'spp-media-p1/5423e19dc8003768ac83aa...  Tommy Hilfiger
# 42  [{'path': 'spp-media-p1/94c3b7409dc83e9e8801f3...         Versace
# 43  [{'path': 'spp-media-p1/8715fcebf3013e27b8b359...         Vingino
# 44  [{'path': 'spp-media-p1/bfd63918b7083768a77550...           Wheat
# 45  [{'path': 'spp-media-p1/f0b84a5d18d1326fafe3d1...            Joha
# 46  [{'path': 'spp-media-p1/656a98dc367738e0b3bd9b...         Versace
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# 5        False              []
# 6        False              []
# 7        False              []
# 8        False              []
# 9        False              []
# 10       False              []
# 11       False              []
# 12       False              []
# 13       False              []
# 14       False              []
# 15       False              []
# 16        True              []
# 17       False              []
# 18        True              []
# 19       False              []
# 20       False              []
# 21       False              []
# 22       False              []
# 23       False              []
# 24       False              []
# 25        True              []
# 26       False              []
# 27        True              []
# 28        True              []
# 29        True              []
# 30       False              []
# 31       False              []
# 32       False              []
# 33       False              []
# 34       False              []
# 35       False              []
# 36       False              []
# 37       False              []
# 38        True              []
# 39        True              []
# 40       False              []
# 41       False              []
# 42        True              []
# 43       False              []
# 44       False              []
# 45       False              []
# 46        True              []
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 1   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 2   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 3   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 4   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 5   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 6   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 7   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 8   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 9   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 10  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     nightwear
# 11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     nightwear
# 12  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 13  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 14  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 15  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 16  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     nightwear
# 17  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     nightwear
# 18  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     nightwear
# 19  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 20  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 21  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 22  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 23  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 24  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 25  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 26  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 27  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 28  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 29  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 30  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     nightwear
# 31  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 32  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 33  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 34  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 35  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 36  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 37  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 38  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 39  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 40  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 41  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 42  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 43  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 44  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     nightwear
# 45  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
# 46  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...     underwear
#
#                                     delivery_promises price.original  \
# 0                                                  []        10,95 €
# 1                                                  []         9,95 €
# 2                                                  []        18,95 €
# 3                                                  []         9,95 €
# 4                                                  []        15,95 €
# 5                                                  []         6,95 €
# 6                                                  []         8,95 €
# 7                                                  []        17,95 €
# 8                                                  []        23,95 €
# 9   [{'key': 'slow_delivery_flag', 'label': 'Livra...        13,95 €
# 10                                                 []        21,95 €
# 11                                                 []        23,99 €
# 12                                                 []        26,95 €
# 13                                                 []        23,95 €
# 14                                                 []        17,95 €
# 15  [{'key': 'slow_delivery_flag', 'label': 'Livra...        25,95 €
# 16                                                 []        74,95 €
# 17                                                 []        16,95 €
# 18                                                 []        69,95 €
# 19  [{'key': 'slow_delivery_flag', 'label': 'Livra...        27,95 €
# 20                                                 []        30,95 €
# 21                                                 []        19,95 €
# 22                                                 []        27,95 €
# 23                                                 []        17,95 €
# 24                                                 []        17,95 €
# 25                                                 []        23,95 €
# 26  [{'key': 'slow_delivery_flag', 'label': 'Livra...        23,95 €
# 27                                                 []        30,95 €
# 28                                                 []        47,95 €
# 29  [{'key': 'slow_delivery_flag', 'label': 'Livra...        47,95 €
# 30  [{'key': 'slow_delivery_flag', 'label': 'Livra...        47,95 €
# 31                                                 []        17,95 €
# 32  [{'key': 'slow_delivery_flag', 'label': 'Livra...        15,95 €
# 33  [{'key': 'slow_delivery_flag', 'label': 'Livra...        12,95 €
# 34  [{'key': 'slow_delivery_flag', 'label': 'Livra...        16,95 €
# 35  [{'key': 'slow_delivery_flag', 'label': 'Livra...        11,95 €
# 36                                                 []         9,95 €
# 37  [{'key': 'slow_delivery_flag', 'label': 'Livra...        10,95 €
# 38                                                 []        16,95 €
# 39                                                 []        19,95 €
# 40                                                 []        12,95 €
# 41                                                 []        17,95 €
# 42                                                 []       130,00 €
# 43                                                 []        10,99 €
# 44                                                 []        27,95 €
# 45  [{'key': 'slow_delivery_flag', 'label': 'Livra...        21,95 €
# 46  [{'key': 'slow_delivery_flag', 'label': 'Livra...       180,00 €
#
#    price.promotional  price.has_different_prices  \
# 0            10,95 €                       False
# 1             9,95 €                       False
# 2            18,95 €                       False
# 3             9,95 €                       False
# 4            15,95 €                       False
# 5             6,95 €                       False
# 6             8,95 €                       False
# 7            17,95 €                       False
# 8            23,95 €                       False
# 9            13,95 €                       False
# 10           21,95 €                       False
# 11           23,99 €                       False
# 12           26,95 €                       False
# 13           23,95 €                       False
# 14           17,95 €                       False
# 15           25,95 €                       False
# 16           74,95 €                       False
# 17           16,95 €                       False
# 18           69,95 €                       False
# 19           27,95 €                       False
# 20           30,95 €                       False
# 21           19,95 €                       False
# 22           27,95 €                       False
# 23           17,95 €                       False
# 24           17,95 €                       False
# 25           23,95 €                       False
# 26           23,95 €                       False
# 27           30,95 €                       False
# 28           47,95 €                       False
# 29           47,95 €                       False
# 30           47,95 €                       False
# 31           17,95 €                       False
# 32           15,95 €                       False
# 33           12,95 €                       False
# 34           16,95 €                       False
# 35           11,95 €                       False
# 36            9,95 €                       False
# 37           10,95 €                       False
# 38           16,95 €                       False
# 39           19,95 €                       False
# 40           12,95 €                       False
# 41           17,95 €                       False
# 42          130,00 €                       False
# 43           10,99 €                       False
# 44           27,95 €                       False
# 45           21,95 €                       False
# 46          180,00 €                       False
#
#     price.has_different_original_prices  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# 5                                 False
# 6                                 False
# 7                                 False
# 8                                 False
# 9                                 False
# 10                                False
# 11                                False
# 12                                False
# 13                                False
# 14                                False
# 15                                False
# 16                                False
# 17                                False
# 18                                False
# 19                                False
# 20                                False
# 21                                False
# 22                                False
# 23                                False
# 24                                False
# 25                                False
# 26                                False
# 27                                False
# 28                                False
# 29                                False
# 30                                False
# 31                                False
# 32                                False
# 33                                False
# 34                                False
# 35                                False
# 36                                False
# 37                                False
# 38                                False
# 39                                False
# 40                                False
# 41                                False
# 42                                False
# 43                                False
# 44                                False
# 45                                False
# 46                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
# 7                                    False
# 8                                    False
# 9                                    False
# 10                                   False
# 11                                   False
# 12                                   False
# 13                                   False
# 14                                   False
# 15                                   False
# 16                                   False
# 17                                   False
# 18                                   False
# 19                                   False
# 20                                   False
# 21                                   False
# 22                                   False
# 23                                   False
# 24                                   False
# 25                                   False
# 26                                   False
# 27                                   False
# 28                                   False
# 29                                   False
# 30                                   False
# 31                                   False
# 32                                   False
# 33                                   False
# 34                                   False
# 35                                   False
# 36                                   False
# 37                                   False
# 38                                   False
# 39                                   False
# 40                                   False
# 41                                   False
# 42                                   False
# 43                                   False
# 44                                   False
# 45                                   False
# 46                                   False
#
#     price.has_discount_on_selected_sizes_only
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# 6                                       False
# 7                                       False
# 8                                       False
# 9                                       False
# 10                                      False
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                      False
# 15                                      False
# 16                                      False
# 17                                      False
# 18                                      False
# 19                                      False
# 20                                      False
# 21                                      False
# 22                                      False
# 23                                      False
# 24                                      False
# 25                                      False
# 26                                      False
# 27                                      False
# 28                                      False
# 29                                      False
# 30                                      False
# 31                                      False
# 32                                      False
# 33                                      False
# 34                                      False
# 35                                      False
# 36                                      False
# 37                                      False
# 38                                      False
# 39                                      False
# 40                                      False
# 41                                      False
# 42                                      False
# 43                                      False
# 44                                      False
# 45                                      False
# 46                                      False

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
# <ipython-input-28-2b69417eb114>:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-28-2b69417eb114>:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#                                                             name  \
# sku
# JAN24B004-Q11                             Pantalon cargo - black
# NI114D0CS-Q12            COURT BOROUGH  - Baskets basses - black
# LE224A08D-Q11       LVB 512 SLIM TAPER JEANS - Jean slim - hydra
# GP024K09I-K11  BOY CAMPUS LOGO HOOD - Sweat à capuche - blue ...
# C1853E00F-Q11                LOGO BELT UNISEX - Ceinture - black
# ...                                                          ...
# 1VE83A001-F11                  MANICA CORTA BABY - Body - bianco
# V2083A01N-J11               TIGER SINGLET - Caraco - pink fusion
# WHA86B002-K11                       THUMPER BABY - Pyjama - dove
# JH184A02T-K11                   LONG SLEEVES - Body - china blue
# 1VE24D000-J11               REGALO BABY SET - Body - rosa/stampa
#
#                                                           sizes  \
# sku
# JAN24B004-Q11       [8a, 9a, 10a, 11a, 12a, 13a, 14a, 15a, 16a]
# NI114D0CS-Q12  [28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5, 34, 35]
# LE224A08D-Q11                  [5a, 6a, 8a, 10a, 12a, 14a, 16a]
# GP024K09I-K11              [6-7a, 8-9a, 10-11a, 12-13a, 14-16a]
# C1853E00F-Q11                                          [70, 80]
# ...                                                         ...
# 1VE83A001-F11                                            [6-9m]
# V2083A01N-J11                                        [14a, 16a]
# WHA86B002-K11                                              [6m]
# JH184A02T-K11                                            [0-1m]
# 1VE24D000-J11                                            [0-3m]
#
#                                                          url_key  \
# sku
# JAN24B004-Q11  jackandjones-junior-pantalon-cargo-black-jan24...
# NI114D0CS-Q12  nike-sportswear-court-borough-baskets-basses-n...
# LE224A08D-Q11      levisr-512-slim-taper-jean-slim-le224a08d-q11
# GP024K09I-K11  gap-boys-v-new-campus-logo-hood-sweatshirt-blu...
# C1853E00F-Q11  calvin-klein-jeans-logo-belt-ceinture-black-c1...
# ...                                                          ...
# 1VE83A001-F11  versace-manica-corta-baby-body-bianco-1ve83a00...
# V2083A01N-J11  vingino-tiger-singlet-caraco-pink-fusion-v2083...
# WHA86B002-K11       wheat-thumper-baby-pyjama-dove-wha86b002-k11
# JH184A02T-K11    joha-long-sleeves-body-china-blue-jh184a02t-k11
# 1VE24D000-J11  versace-regalo-baby-set-body-rosastampa-1ve24d...
#
#                                                            media  \
# sku
# JAN24B004-Q11  [{'path': 'spp-media-p1/6272154bdaec3231bf44b9...
# NI114D0CS-Q12  [{'path': 'spp-media-p1/5d261560a1373fc0ae8911...
# LE224A08D-Q11  [{'path': 'spp-media-p1/6d4d2e7e747e34d5a9b4b8...
# GP024K09I-K11  [{'path': 'spp-media-p1/db2ddaacb7e33199bf62d0...
# C1853E00F-Q11  [{'path': 'spp-media-p1/25b08a59481536469d7391...
# ...                                                          ...
# 1VE83A001-F11  [{'path': 'spp-media-p1/94c3b7409dc83e9e8801f3...
# V2083A01N-J11  [{'path': 'spp-media-p1/8715fcebf3013e27b8b359...
# WHA86B002-K11  [{'path': 'spp-media-p1/bfd63918b7083768a77550...
# JH184A02T-K11  [{'path': 'spp-media-p1/f0b84a5d18d1326fafe3d1...
# 1VE24D000-J11  [{'path': 'spp-media-p1/656a98dc367738e0b3bd9b...
#
#                         brand_name  is_premium family_articles  \
# sku
# JAN24B004-Q11  Jack & Jones Junior       False              []
# NI114D0CS-Q12      Nike Sportswear       False              []
# LE224A08D-Q11              Levi's®       False              []
# GP024K09I-K11                  GAP       False              []
# C1853E00F-Q11   Calvin Klein Jeans       False              []
# ...                            ...         ...             ...
# 1VE83A001-F11              Versace        True              []
# V2083A01N-J11              Vingino       False              []
# WHA86B002-K11                Wheat       False              []
# JH184A02T-K11                 Joha       False              []
# 1VE24D000-J11              Versace        True              []
#
#                                                            flags  \
# sku
# JAN24B004-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# NI114D0CS-Q12  [{'key': 'discountRate', 'value': '-25%', 'tra...
# LE224A08D-Q11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# GP024K09I-K11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# C1853E00F-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# ...                                                          ...
# 1VE83A001-F11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# V2083A01N-J11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# WHA86B002-K11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# JH184A02T-K11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# 1VE24D000-J11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
#
#               product_group  \
# sku
# JAN24B004-Q11      clothing
# NI114D0CS-Q12          shoe
# LE224A08D-Q11      clothing
# GP024K09I-K11      clothing
# C1853E00F-Q11   accessoires
# ...                     ...
# 1VE83A001-F11     underwear
# V2083A01N-J11     underwear
# WHA86B002-K11     nightwear
# JH184A02T-K11     underwear
# 1VE24D000-J11     underwear
#
#                                                delivery_promises  \
# sku
# JAN24B004-Q11                                                 []
# NI114D0CS-Q12                                                 []
# LE224A08D-Q11                                                 []
# GP024K09I-K11                                                 []
# C1853E00F-Q11                                                 []
# ...                                                          ...
# 1VE83A001-F11                                                 []
# V2083A01N-J11                                                 []
# WHA86B002-K11                                                 []
# JH184A02T-K11  [{'key': 'slow_delivery_flag', 'label': 'Livra...
# 1VE24D000-J11  [{'key': 'slow_delivery_flag', 'label': 'Livra...
#
#               price.original price.promotional  price.has_different_prices  \
# sku
# JAN24B004-Q11        49,95 €           34,95 €                       False
# NI114D0CS-Q12        32,95 €           24,65 €                       False
# LE224A08D-Q11        34,95 €           26,15 €                        True
# GP024K09I-K11        26,95 €           20,25 €                       False
# C1853E00F-Q11        24,95 €           17,55 €                       False
# ...                      ...               ...                         ...
# 1VE83A001-F11       130,00 €          130,00 €                       False
# V2083A01N-J11        10,99 €           10,99 €                       False
# WHA86B002-K11        27,95 €           27,95 €                       False
# JH184A02T-K11        21,95 €           21,95 €                       False
# 1VE24D000-J11       180,00 €          180,00 €                       False
#
#                price.has_different_original_prices  \
# sku
# JAN24B004-Q11                                False
# NI114D0CS-Q12                                False
# LE224A08D-Q11                                False
# GP024K09I-K11                                False
# C1853E00F-Q11                                False
# ...                                            ...
# 1VE83A001-F11                                False
# V2083A01N-J11                                False
# WHA86B002-K11                                False
# JH184A02T-K11                                False
# 1VE24D000-J11                                False
#
#                price.has_different_promotional_prices  \
# sku
# JAN24B004-Q11                                   False
# NI114D0CS-Q12                                   False
# LE224A08D-Q11                                    True
# GP024K09I-K11                                   False
# C1853E00F-Q11                                   False
# ...                                               ...
# 1VE83A001-F11                                   False
# V2083A01N-J11                                   False
# WHA86B002-K11                                   False
# JH184A02T-K11                                   False
# 1VE24D000-J11                                   False
#
#                price.has_discount_on_selected_sizes_only amount condition  \
# sku
# JAN24B004-Q11                                      False    NaN       NaN
# NI114D0CS-Q12                                      False    NaN       NaN
# LE224A08D-Q11                                      False    NaN       NaN
# GP024K09I-K11                                      False    NaN       NaN
# C1853E00F-Q11                                      False    NaN       NaN
# ...                                                  ...    ...       ...
# 1VE83A001-F11                                      False    NaN       NaN
# V2083A01N-J11                                      False    NaN       NaN
# WHA86B002-K11                                      False    NaN       NaN
# JH184A02T-K11                                      False    NaN       NaN
# 1VE24D000-J11                                      False    NaN       NaN
#
#               condition_key
# sku
# JAN24B004-Q11           NaN
# NI114D0CS-Q12           NaN
# LE224A08D-Q11           NaN
# GP024K09I-K11           NaN
# C1853E00F-Q11           NaN
# ...                     ...
# 1VE83A001-F11           NaN
# V2083A01N-J11           NaN
# WHA86B002-K11           NaN
# JH184A02T-K11           NaN
# 1VE24D000-J11           NaN
#
# [23233 rows x 19 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Name it'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Boboli'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# brand_name
# 3 Pommes         0.0
# 8848 Altitude    0.0
# ALDO             0.0
# BOSS Kidswear    0.0
# Be Only          0.0
#                 ...
# bellybutton      0.0
# igi natur        0.0
# mikk-line        0.0
# mothercare       0.0
# shoeb76          0.0
# Name: discount_amount, Length: 91, dtype: float64
